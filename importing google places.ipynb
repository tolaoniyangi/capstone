# %%
import requests
import json

import googlemaps

# %%
keys_file = open("gcs_key.txt")
APIKEY = keys_file.read().strip()

# %%
total_results = []
types = ["bar","cafe","restaurant"]
# types = ["bar","cafe","casino","movie_theater","night_club","park","restaurant","shopping_mall","zoo"]

for i in types:
    def findPlaces(pagetoken = None):
        lat, lng = ('40.7589','-73.9851')
        radius=420
    #     type = "restaurant"
        url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={lat},{lng}&radius={radius}&fields=name,geometry,types,price_level&type={type}&key={APIKEY}{pagetoken}".format(lat = lat, lng = lng, radius = radius, type = type,APIKEY = APIKEY, pagetoken = "&pagetoken="+pagetoken if pagetoken else "")
        print(url)

        response = requests.get(url)
        res = json.loads(response.text)
        print("here results ---->>> ", len(res["results"]))

        for result in res["results"]:
    #         info = ";".join(map(str,[result["name"],result["geometry"]["location"]["lat"],result["geometry"]["location"]["lng"],result.get("rating",0),result["place_id"]]))
    #         print(info)

            place_name = result['name']
            latitude = result["geometry"]["location"]["lat"]
            longitude = result["geometry"]["location"]["lng"]
            place_type = result.get("types",0)
            price_level = result.get("price_level",0)
    #         print([place_type, place_name, latitude, longitude])
            total_results.append([latitude, longitude, place_name,place_type,price_level])
    #         total_results.append(result)
        pagetoken = res.get("next_page_token",None)

        print("here -->> ", pagetoken)

        return pagetoken

    pagetoken = None

    while True:
         pagetoken = findPlaces(pagetoken=pagetoken)
         import time
         time.sleep(5)

         if not pagetoken:
             break
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=40.7589,-73.9851&radius=420&fields=name,geometry,types,price_level&type=bar&key=AIzaSyC0y-qTQ7hTYTaJczSYgzkTE-dOeiGt79g
# here results ---->>>  20
# here -->>  CqQCGAEAAI7vTsEq8dXqI6NJLE68Gd54sclmkd69oCadEycIIN0Pdde9NB7eOTmqdOz3V8P2eumKFLw4oebQNZyjIQfkDZwvIbPz_1h4Zrw5FkAGlpyzMn5dj8Z4IYWSguZ1DI4FtFzBfD40fELDVy8332LE9_16yuFmAYFCkVLY2o7PJusRkLl4DvRRvEYtSirSVVV8Etq8RygdG8ROsLmLykfApnYWp65RFgb-K-IQAQt6MbCxs3ACr-uaFdVDeKlCZrxKRESZb4YiiGZdEABBzKVKBrk9dEEAgWxKG8FtqhW_zAwURKA25ZN2gwxekPOi1Dr-FCwQvr4XoDoEOxaMwiEi3ax4DsOq4Fm3_4FRSd6HEflKUh09wyWfpADDu5kpp4_xAhIQfsl3u_hLq1EgzpVLWxISlRoU57Fikqxh3dzUWfaRiCrOpsYX7Og
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=40.7589,-73.9851&radius=420&fields=name,geometry,types,price_level&type=bar&key=AIzaSyC0y-qTQ7hTYTaJczSYgzkTE-dOeiGt79g&pagetoken=CqQCGAEAAI7vTsEq8dXqI6NJLE68Gd54sclmkd69oCadEycIIN0Pdde9NB7eOTmqdOz3V8P2eumKFLw4oebQNZyjIQfkDZwvIbPz_1h4Zrw5FkAGlpyzMn5dj8Z4IYWSguZ1DI4FtFzBfD40fELDVy8332LE9_16yuFmAYFCkVLY2o7PJusRkLl4DvRRvEYtSirSVVV8Etq8RygdG8ROsLmLykfApnYWp65RFgb-K-IQAQt6MbCxs3ACr-uaFdVDeKlCZrxKRESZb4YiiGZdEABBzKVKBrk9dEEAgWxKG8FtqhW_zAwURKA25ZN2gwxekPOi1Dr-FCwQvr4XoDoEOxaMwiEi3ax4DsOq4Fm3_4FRSd6HEflKUh09wyWfpADDu5kpp4_xAhIQfsl3u_hLq1EgzpVLWxISlRoU57Fikqxh3dzUWfaRiCrOpsYX7Og
# here results ---->>>  20
# here -->>  CsQDuAEAAFaNN_IK8IyjzhRKNWW2OEhilNVaZ7OO9VQTxBw5m2k6GZz7dihgYwaHSXFaX9hUat7Lkcv5Xro0bylMKzbE3IPfcR-oFv2yJNqgybxs86jJ65dZHpkSygme3Qx0v6HCs5JsGGVaHmhIOq1hqML9BjYZXdE-UKPUHIMlI3Dc_Xubp3Uvf4JHijE9xITPI0V1XDLAjA7ikUTgoxQY5p_2Tw1H6a3bXzGfOGl1hZpGVDeUZJHIuF-lXRXqlUOmasmHzA04nKE_DNpKjEisyWpH5nfW1HRl-Ivd8YAHTvf4JBSYCQEV6gzUe05SVqXsWCSd303wAY8tGEQB9Djjyhzchs_x9hywqvVafczgkcdl5NOyOtzpJw28RCfdKpn8pfJUyt7gdqta0n4xSBZCB-stte-PVR6JbidBKjh0ET3gQnETvrXSaaOU7jrmqoN0t5jN1BfiytGGSsZnQll128V7VkosUw8yxeoNi0DxpaFXBe7bcnOTgmAZT6drhXwS2enRbyPqPzXDovAZ6AfbqlD-SneAbCCnm4Nvx_f8jWSqD7-HVkSxFhfkNJMXQSaPlrkwuSX8XnK9oWZvIm6GbNmxtp8SEBkumWlEdG3f6B1KIulINAkaFONTVOP6vke7AWYBVMBEZ6WIiloH
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=40.7589,-73.9851&radius=420&fields=name,geometry,types,price_level&type=bar&key=AIzaSyC0y-qTQ7hTYTaJczSYgzkTE-dOeiGt79g&pagetoken=CsQDuAEAAFaNN_IK8IyjzhRKNWW2OEhilNVaZ7OO9VQTxBw5m2k6GZz7dihgYwaHSXFaX9hUat7Lkcv5Xro0bylMKzbE3IPfcR-oFv2yJNqgybxs86jJ65dZHpkSygme3Qx0v6HCs5JsGGVaHmhIOq1hqML9BjYZXdE-UKPUHIMlI3Dc_Xubp3Uvf4JHijE9xITPI0V1XDLAjA7ikUTgoxQY5p_2Tw1H6a3bXzGfOGl1hZpGVDeUZJHIuF-lXRXqlUOmasmHzA04nKE_DNpKjEisyWpH5nfW1HRl-Ivd8YAHTvf4JBSYCQEV6gzUe05SVqXsWCSd303wAY8tGEQB9Djjyhzchs_x9hywqvVafczgkcdl5NOyOtzpJw28RCfdKpn8pfJUyt7gdqta0n4xSBZCB-stte-PVR6JbidBKjh0ET3gQnETvrXSaaOU7jrmqoN0t5jN1BfiytGGSsZnQll128V7VkosUw8yxeoNi0DxpaFXBe7bcnOTgmAZT6drhXwS2enRbyPqPzXDovAZ6AfbqlD-SneAbCCnm4Nvx_f8jWSqD7-HVkSxFhfkNJMXQSaPlrkwuSX8XnK9oWZvIm6GbNmxtp8SEBkumWlEdG3f6B1KIulINAkaFONTVOP6vke7AWYBVMBEZ6WIiloH
# here results ---->>>  16
# here -->>  None
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=40.7589,-73.9851&radius=420&fields=name,geometry,types,price_level&type=cafe&key=AIzaSyC0y-qTQ7hTYTaJczSYgzkTE-dOeiGt79g
# here results ---->>>  20
# here -->>  CqQCGQEAADEDcy3ROIfq8U2sSeCiTJRabb0MkQLaCFZ9h9o7FaQu33D2963wR5pYi6tKTIrvtauLJKDx4Tj9R3t6G4-K-ypX_vOhGLL1vIXNWt7pI_AE-Ntq0xoDvsERQTnPuv0PLxfK3Q4BegMvpLwxUGBx8U-cpPJML8FFYct9ROFb7hlTqAEuf2iu5A7IYszqzuyXyRgvqMQ3OfSII-dAzyr-M-GtMIsqfQC3Xf9xVFmn7uyFLT1Cl10UhEDvQKwq30vZ17ua3U1xNCwGVc8WK4IFulupABgPu_Ulu2g_hwhUQzLn4q1f_SL_FDWzF7mZ4EugOieMpvHugKdS0kZ86S4jt2Gg_mRARqnj5ajjibxwfFSxTVoc_2navTfKSJm_2e-4dBIQiWyhs9S2o2PftBaZA7YhkhoUFyjWg_lBtoEcpInoRer4vXstSHE
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=40.7589,-73.9851&radius=420&fields=name,geometry,types,price_level&type=cafe&key=AIzaSyC0y-qTQ7hTYTaJczSYgzkTE-dOeiGt79g&pagetoken=CqQCGQEAADEDcy3ROIfq8U2sSeCiTJRabb0MkQLaCFZ9h9o7FaQu33D2963wR5pYi6tKTIrvtauLJKDx4Tj9R3t6G4-K-ypX_vOhGLL1vIXNWt7pI_AE-Ntq0xoDvsERQTnPuv0PLxfK3Q4BegMvpLwxUGBx8U-cpPJML8FFYct9ROFb7hlTqAEuf2iu5A7IYszqzuyXyRgvqMQ3OfSII-dAzyr-M-GtMIsqfQC3Xf9xVFmn7uyFLT1Cl10UhEDvQKwq30vZ17ua3U1xNCwGVc8WK4IFulupABgPu_Ulu2g_hwhUQzLn4q1f_SL_FDWzF7mZ4EugOieMpvHugKdS0kZ86S4jt2Gg_mRARqnj5ajjibxwfFSxTVoc_2navTfKSJm_2e-4dBIQiWyhs9S2o2PftBaZA7YhkhoUFyjWg_lBtoEcpInoRer4vXstSHE
# here results ---->>>  20
# here -->>  CsQDuQEAAEDaOSXXNYiKbY61xnnSsuCY_Sp1HDMSL0l2TD1GKZlZRuzwA1eyP6Av94n1Qc_o3snwq5-JxGhnxLzFTFhBr9yaO2SPNVqhqTqwKWDm_vUu3XE1nSHdHQxwFByQDFOa81Im-aLuSWbhCiLM6fpfcqGdyuDp68U4OxevYcLzDOZuad6vcYUi9ZHXOnNRlWckFzQkLKunpu8fXRl7n1snuWalVdfyY5pE1S4oWer8J3VcS370KG-9RM4MJiBmp5MAiEMaQKjfRBvrbNiaeDhpD6vZ_S53R3cm15NZZe7mHVPjWa3lISb3WKANfGLMJNi8FXAUVIHYHnRM1yT7VergEOV3acIApc2oPMA-Ye-0LFrra_CT7pt76OhQJZgywCRsNeyh6A_NUg-Y_AlCPa0IAr8eeOuRszXujOXAkFeqEtpuamOsRhjtG53T-uDT5iQb5leWHRlzgwDo3rJARoS1CR6vPBJxDLB7CnGrQmSLQS3vHKUHTQotjSJ7qRlO1fw2vd17yRiyWlAjBq75LN7yAJ3XhjgFN1hdpMk2AzIxD3Fds1FubQOeng4eV_xlSYIDpwDBR0ZWFS9wRF1BUPuoFOoSEN8VsL0YDy1pe6oa0gG3iYwaFHPTrKstRHl_p3HZiX9W39GqlJbg
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=40.7589,-73.9851&radius=420&fields=name,geometry,types,price_level&type=cafe&key=AIzaSyC0y-qTQ7hTYTaJczSYgzkTE-dOeiGt79g&pagetoken=CsQDuQEAAEDaOSXXNYiKbY61xnnSsuCY_Sp1HDMSL0l2TD1GKZlZRuzwA1eyP6Av94n1Qc_o3snwq5-JxGhnxLzFTFhBr9yaO2SPNVqhqTqwKWDm_vUu3XE1nSHdHQxwFByQDFOa81Im-aLuSWbhCiLM6fpfcqGdyuDp68U4OxevYcLzDOZuad6vcYUi9ZHXOnNRlWckFzQkLKunpu8fXRl7n1snuWalVdfyY5pE1S4oWer8J3VcS370KG-9RM4MJiBmp5MAiEMaQKjfRBvrbNiaeDhpD6vZ_S53R3cm15NZZe7mHVPjWa3lISb3WKANfGLMJNi8FXAUVIHYHnRM1yT7VergEOV3acIApc2oPMA-Ye-0LFrra_CT7pt76OhQJZgywCRsNeyh6A_NUg-Y_AlCPa0IAr8eeOuRszXujOXAkFeqEtpuamOsRhjtG53T-uDT5iQb5leWHRlzgwDo3rJARoS1CR6vPBJxDLB7CnGrQmSLQS3vHKUHTQotjSJ7qRlO1fw2vd17yRiyWlAjBq75LN7yAJ3XhjgFN1hdpMk2AzIxD3Fds1FubQOeng4eV_xlSYIDpwDBR0ZWFS9wRF1BUPuoFOoSEN8VsL0YDy1pe6oa0gG3iYwaFHPTrKstRHl_p3HZiX9W39GqlJbg
# here results ---->>>  4
# here -->>  None
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=40.7589,-73.9851&radius=420&fields=name,geometry,types,price_level&type=casino&key=AIzaSyC0y-qTQ7hTYTaJczSYgzkTE-dOeiGt79g
# here results ---->>>  0
# here -->>  None
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=40.7589,-73.9851&radius=420&fields=name,geometry,types,price_level&type=movie_theater&key=AIzaSyC0y-qTQ7hTYTaJczSYgzkTE-dOeiGt79g
# here results ---->>>  3
# here -->>  None
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=40.7589,-73.9851&radius=420&fields=name,geometry,types,price_level&type=night_club&key=AIzaSyC0y-qTQ7hTYTaJczSYgzkTE-dOeiGt79g
# here results ---->>>  0
# here -->>  None
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=40.7589,-73.9851&radius=420&fields=name,geometry,types,price_level&type=park&key=AIzaSyC0y-qTQ7hTYTaJczSYgzkTE-dOeiGt79g
# here results ---->>>  6
# here -->>  None
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=40.7589,-73.9851&radius=420&fields=name,geometry,types,price_level&type=restaurant&key=AIzaSyC0y-qTQ7hTYTaJczSYgzkTE-dOeiGt79g
# here results ---->>>  20
# here -->>  CqQCHwEAAJKnpotjI211iR5_xFDVe8Dv8MblaQgxCwNytEXI7uQzJgYQjhBZcnLMi05CVA9keOQvUMvbIwlUWh1F0hIEBa_w--xXxDNzDqhX5nt0txphMjAPNQVe87lYqcj_q04_cViw1xV4VltdI-DC7Gc8qMZNl0JD-gyOeLVIAggMlzVZPfFaaXGO5IMn9oIyB801Bw8NZ-JWqSwjlyoDCG57vF77GRc0Am5YzMJsOBdbOHlqLQux33OOaAdscsOflCTSciaF3pRXS-Iq2GjJkR0uZOQ-0DCT-8eodiU72cEQPmfDTYHaqpDyLCYcKNz6wgFyadNdXixjijLrAIygwr-oZ_MCzZW2ofln6Gau7n6nkbNEqsVJ-c2FjYxerlFlvBN4GxIQmiVl-xHDoG5WXoWpt_V5URoUckHrSWWscx0x8Kub3OaS-RwTWtg
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=40.7589,-73.9851&radius=420&fields=name,geometry,types,price_level&type=restaurant&key=AIzaSyC0y-qTQ7hTYTaJczSYgzkTE-dOeiGt79g&pagetoken=CqQCHwEAAJKnpotjI211iR5_xFDVe8Dv8MblaQgxCwNytEXI7uQzJgYQjhBZcnLMi05CVA9keOQvUMvbIwlUWh1F0hIEBa_w--xXxDNzDqhX5nt0txphMjAPNQVe87lYqcj_q04_cViw1xV4VltdI-DC7Gc8qMZNl0JD-gyOeLVIAggMlzVZPfFaaXGO5IMn9oIyB801Bw8NZ-JWqSwjlyoDCG57vF77GRc0Am5YzMJsOBdbOHlqLQux33OOaAdscsOflCTSciaF3pRXS-Iq2GjJkR0uZOQ-0DCT-8eodiU72cEQPmfDTYHaqpDyLCYcKNz6wgFyadNdXixjijLrAIygwr-oZ_MCzZW2ofln6Gau7n6nkbNEqsVJ-c2FjYxerlFlvBN4GxIQmiVl-xHDoG5WXoWpt_V5URoUckHrSWWscx0x8Kub3OaS-RwTWtg
# here results ---->>>  0
# here -->>  None
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=40.7589,-73.9851&radius=420&fields=name,geometry,types,price_level&type=shopping_mall&key=AIzaSyC0y-qTQ7hTYTaJczSYgzkTE-dOeiGt79g
# here results ---->>>  0
# here -->>  None
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=40.7589,-73.9851&radius=420&fields=name,geometry,types,price_level&type=zoo&key=AIzaSyC0y-qTQ7hTYTaJczSYgzkTE-dOeiGt79g
# here results ---->>>  0
# here -->>  None

# %%
# total_results
# Out:
# [[40.7594099,
#   -73.98222,
#   "Del Frisco's Double Eagle Steakhouse",
#   ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   4],
#  [40.7595183,
#   -73.9847419,
#   'Olive Garden Italian Restaurant',
#   ['meal_takeaway',
#    'bar',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   2],
#  [40.7589876,
#   -73.9863247,
#   'The View Restaurant & Lounge',
#   ['night_club',
#    'bar',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   4],
#  [40.7599972,
#   -73.9867421,
#   'Trattoria Trecolori',
#   ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   2],
#  [40.7583364,
#   -73.9841591,
#   'Havana Central Times Square',
#   ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   2],
#  [40.756511,
#   -73.984641,
#   'The Lambs Club',
#   ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   3],
#  [40.76088499999999,
#   -73.9863,
#   'La Masseria',
#   ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   3],
#  [40.75799560000001,
#   -73.9828606,
#   'Utsav',
#   ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   2],
#  [40.757732,
#   -73.987218,
#   'Bowlmor Times Square',
#   ['bowling_alley',
#    'bar',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   3],
#  [40.7574092,
#   -73.9837409,
#   'The Perfect Pint',
#   ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   2],
#  [40.7596193,
#   -73.9846788,
#   'R Lounge',
#   ['night_club',
#    'bar',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   2],
#  [40.7592458,
#   -73.98629249999999,
#   'Bond 45 NY',
#   ['night_club',
#    'bar',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   2],
#  [40.7611053,
#   -73.9825075,
#   "Bobby Van's",
#   ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   3],
#  [40.7605555,
#   -73.98613399999999,
#   "Hurley's Restaurant & Bar",
#   ['restaurant', 'bar', 'food', 'point_of_interest', 'establishment'],
#   2],
#  [40.761896,
#   -73.983525,
#   'The Iridium',
#   ['night_club',
#    'bar',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   3],
#  [40.7599063,
#   -73.9866799,
#   'Glass House Tavern',
#   ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   2],
#  [40.760932,
#   -73.987522,
#   'Latitude Bar & Grill',
#   ['restaurant', 'bar', 'food', 'point_of_interest', 'establishment'],
#   2],
#  [40.7614517,
#   -73.981861,
#   'Le Bernardin',
#   ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   4],
#  [40.7569778,
#   -73.98877499999999,
#   'Dallas BBQ',
#   ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   2],
#  [40.7565383,
#   -73.9886358,
#   "Dave & Buster's",
#   ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   2],
#  [40.7576169,
#   -73.9843645,
#   "O'Lunney's",
#   ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   2],
#  [40.7593096,
#   -73.98253270000001,
#   '48 Lounge',
#   ['night_club',
#    'bar',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   3],
#  [40.7616634,
#   -73.9851809,
#   'Natsumi',
#   ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   2],
#  [40.7591328,
#   -73.9898984,
#   'Gyu-Kaku Japanese BBQ',
#   ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   2],
#  [40.759983,
#   -73.982845,
#   'Pasta Lovers',
#   ['bar', 'restaurant', 'food', 'point_of_interest', 'store', 'establishment'],
#   2],
#  [40.759426,
#   -73.988742,
#   'Kodama Sushi',
#   ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   2],
#  [40.7558542,
#   -73.9822222,
#   'db Bistro Moderne',
#   ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   3],
#  [40.756419,
#   -73.984331,
#   'Saju Bistro',
#   ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   3],
#  [40.7601055,
#   -73.9892498,
#   'Brazil Brazil',
#   ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   2],
#  [40.7611327,
#   -73.9829467,
#   'TGI Fridays',
#   ['restaurant',
#    'meal_takeaway',
#    'bar',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   2],
#  [40.76021920000001,
#   -73.9895726,
#   'Le Rivage',
#   ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   3],
#  [40.7570272,
#   -73.983916,
#   "Bobby Van's Grill Times Square",
#   ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   3],
#  [40.7623127,
#   -73.9848901,
#   'Azalea',
#   ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   3],
#  [40.7593774,
#   -73.9872431,
#   'Pergola Des Artistes',
#   ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   2],
#  [40.7603837,
#   -73.9896503,
#   'Meson Sevilla',
#   ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   2],
#  [40.76166679999999,
#   -73.986858,
#   'West End Bar & Grill',
#   ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   2],
#  [40.7583499,
#   -73.98418079999999,
#   'TGI Fridays',
#   ['restaurant',
#    'meal_takeaway',
#    'bar',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   2],
#  [40.7584139,
#   -73.98319959999999,
#   'Tender Steak & Sushi',
#   ['night_club',
#    'bar',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   2],
#  [40.76018639999999,
#   -73.9863847,
#   'Buffalo Wild Wings',
#   ['meal_takeaway',
#    'bar',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   2],
#  [40.7583509,
#   -73.9887543,
#   'Roxy Diner',
#   ['bar', 'restaurant', 'food', 'point_of_interest', 'store', 'establishment'],
#   2],
#  [40.7582948,
#   -73.98880079999999,
#   'Retroclubnyc',
#   ['night_club',
#    'bar',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   0],
#  [40.7615138,
#   -73.98693089999999,
#   'Times Square Diner & Grill',
#   ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   2],
#  [40.7576363,
#   -73.9892821,
#   'Foundry Kitchen & Bar',
#   ['restaurant', 'bar', 'food', 'point_of_interest', 'establishment'],
#   0],
#  [40.7593023,
#   -73.99004579999999,
#   "Hell's Kitchen Hospitality",
#   ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   0],
#  [40.7585485,
#   -73.9859682,
#   'Crossroads',
#   ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   2],
#  [40.7588452,
#   -73.98393039999999,
#   'The Long Acre Tavern',
#   ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   0],
#  [40.760478,
#   -73.98416,
#   'Celtic Pub Restaurant',
#   ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   0],
#  [40.7582981,
#   -73.9826791,
#   'Taco Dumbo',
#   ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   0],
#  [40.75935370000001,
#   -73.98790559999999,
#   'Playright Tavern',
#   ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   0],
#  [40.7591086,
#   -73.98869189999999,
#   'Margarita Bar NYC',
#   ['night_club',
#    'bar',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   0],
#  [40.7582948,
#   -73.98880079999999,
#   "Gayle's Broadway Rose",
#   ['restaurant', 'bar', 'food', 'point_of_interest', 'establishment'],
#   0],
#  [40.758903,
#   -73.98897199999999,
#   'Secret Room New York',
#   ['night_club',
#    'bar',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   0],
#  [40.76033,
#   -73.988631,
#   'Vodka Soda Bottoms Up',
#   ['night_club', 'bar', 'point_of_interest', 'establishment'],
#   1],
#  [40.757977,
#   -73.98116120000002,
#   'Federation Building',
#   ['bar', 'general_contractor', 'point_of_interest', 'establishment'],
#   0],
#  [40.75833550000001,
#   -73.98082629999999,
#   'The Elgin',
#   ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   0],
#  [40.75546979999999,
#   -73.9831779,
#   'Bluestone Lane Bryant Park Coffee Shop',
#   ['cafe', 'bar', 'food', 'point_of_interest', 'store', 'establishment'],
#   2],
#  [40.756077,
#   -73.982699,
#   'The Red Flame',
#   ['meal_takeaway',
#    'cafe',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   1],
#  [40.756393,
#   -73.988039,
#   "McDonald's",
#   ['cafe',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   1],
#  [40.75964930000001,
#   -73.9803663,
#   'Mrs. Fields Rockefeller Center',
#   ['bakery', 'cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#   0],
#  [40.762244,
#   -73.983757,
#   "McDonald's",
#   ['cafe',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   1],
#  [40.7574601,
#   -73.982739,
#   'Europa Cafe',
#   ['cafe', 'food', 'point_of_interest', 'establishment'],
#   1],
#  [40.757629,
#   -73.98185,
#   "McDonald's",
#   ['cafe',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   1],
#  [40.7566805,
#   -73.9868137,
#   'Europa Cafe',
#   ['cafe', 'food', 'point_of_interest', 'establishment'],
#   2],
#  [40.7599326,
#   -73.987599,
#   "Dunkin'",
#   ['bakery',
#    'meal_takeaway',
#    'cafe',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   1],
#  [40.7589234,
#   -73.9883193,
#   'Sugar Factory Row NYC',
#   ['cafe', 'food', 'point_of_interest', 'establishment'],
#   3],
#  [40.7580693,
#   -73.9889412,
#   "McDonald's",
#   ['cafe',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   1],
#  [40.7595326,
#   -73.9883524,
#   'Amorino Gelato and Cafe',
#   ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#   2],
#  [40.7577822,
#   -73.98171119999999,
#   'OCD CAFE',
#   ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#   0],
#  [40.7605459,
#   -73.9817316,
#   'Le Pain Quotidien',
#   ['restaurant',
#    'bakery',
#    'cafe',
#    'food',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   2],
#  [40.75762689999999,
#   -73.9891847,
#   'Europan Cafe',
#   ['cafe', 'bakery', 'food', 'point_of_interest', 'store', 'establishment'],
#   2],
#  [40.7554719,
#   -73.9862251,
#   "Jake's @ The Knick",
#   ['cafe', 'food', 'point_of_interest', 'establishment'],
#   0],
#  [40.7608978,
#   -73.9889279,
#   'Frisson Espresso',
#   ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#   2],
#  [40.7575375,
#   -73.9817901,
#   'NYXpresso',
#   ['cafe', 'food', 'point_of_interest', 'establishment'],
#   0],
#  [40.7577822,
#   -73.98171119999999,
#   'Akshar Coffee Shop',
#   ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#   0],
#  [40.7580844,
#   -73.9841515,
#   'Cafe Abbondanza',
#   ['cafe', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   1],
#  [40.7578343,
#   -73.98241949999999,
#   'Simon Sips',
#   ['cafe', 'food', 'point_of_interest', 'establishment'],
#   1],
#  [40.7589829,
#   -73.9855609,
#   'Drink NYC inside AEO',
#   ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#   0],
#  [40.7583564,
#   -73.9847628,
#   'Val Cafe',
#   ['cafe', 'food', 'point_of_interest', 'establishment'],
#   0],
#  [40.7582671,
#   -73.98489579999999,
#   'Farid Orujzadeh Cafè',
#   ['cafe', 'food', 'point_of_interest', 'establishment'],
#   0],
#  [40.75973879999999,
#   -73.9846238,
#   "Mia's Brooklyn Bakery",
#   ['bakery', 'cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#   0],
#  [40.757749,
#   -73.9854003,
#   "McDonald's",
#   ['cafe',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   1],
#  [40.758532,
#   -73.98660699999999,
#   'Starbucks',
#   ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#   2],
#  [40.7601775,
#   -73.9843631,
#   'Gong Cha',
#   ['cafe', 'food', 'point_of_interest', 'establishment'],
#   0],
#  [40.7579144,
#   -73.9831988,
#   'For Five Coffee Times Square',
#   ['bakery', 'cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#   0],
#  [40.7607528,
#   -73.9860889,
#   'Masseria Caffè & Bakery',
#   ['cafe', 'bakery', 'food', 'point_of_interest', 'store', 'establishment'],
#   2],
#  [40.759206,
#   -73.98236709999999,
#   'Zibetto Espresso Bar',
#   ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#   2],
#  [40.760978,
#   -73.985501,
#   'Goldfinch',
#   ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#   2],
#  [40.7601441,
#   -73.98831140000001,
#   'Grab & Go',
#   ['cafe', 'food', 'point_of_interest', 'establishment'],
#   0],
#  [40.7577606,
#   -73.9817462,
#   '47 Rockefeller Deli & Convenience Store',
#   ['convenience_store',
#    'cafe',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   0],
#  [40.75786299999999,
#   -73.98867,
#   'The Times Eatery',
#   ['cafe', 'food', 'point_of_interest', 'establishment'],
#   0],
#  [40.7616986,
#   -73.9862946,
#   'Food To Go',
#   ['cafe',
#    'bakery',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   0],
#  [40.75601489999999,
#   -73.9860436,
#   'Brooklyn Roasting Company Pop Up Cafe at H&M',
#   ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#   0],
#  [40.75722880000001,
#   -73.9886494,
#   'Nguyen Xuan Chinh',
#   ['cafe', 'food', 'point_of_interest', 'establishment'],
#   0],
#  [40.7617278,
#   -73.9870016,
#   'Oriental Tea 茶颜观色',
#   ['cafe', 'food', 'point_of_interest', 'establishment'],
#   0],
#  [40.7616987,
#   -73.9871574,
#   'Modern Tea Shop',
#   ['cafe', 'food', 'point_of_interest', 'establishment'],
#   0],
#  [40.7621201,
#   -73.9841314,
#   'Princi Bakery',
#   ['cafe', 'food', 'point_of_interest', 'establishment'],
#   0],
#  [40.76208340000001,
#   -73.9836569,
#   'Starbucks Reserve',
#   ['cafe', 'food', 'point_of_interest', 'establishment'],
#   0],
#  [40.7617584,
#   -73.9824008,
#   'やたい',
#   ['cafe', 'food', 'point_of_interest', 'establishment'],
#   0],
#  [40.756742,
#   -73.9812924,
#   'Sigma International Inc',
#   ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#   0],
#  [40.75546979999999,
#   -73.9831779,
#   'Bluestone Lane Bryant Park Coffee Shop',
#   ['cafe', 'bar', 'food', 'point_of_interest', 'store', 'establishment'],
#   2],
#  [40.757032,
#   -73.988978,
#   'Regal E-Walk 4DX & RPX',
#   ['movie_theater', 'point_of_interest', 'establishment'],
#   0],
#  [40.7598637,
#   -73.9886736,
#   'A Musical About Star Wars',
#   ['movie_theater', 'point_of_interest', 'establishment'],
#   0],
#  [40.7572802,
#   -73.9829159,
#   'Wonderland Architecture NYC',
#   ['movie_theater', 'point_of_interest', 'establishment'],
#   0],
#  [40.75900769999999,
#   -73.9850222,
#   'Father Duffy Square',
#   ['tourist_attraction', 'park', 'point_of_interest', 'establishment'],
#   0],
#  [40.75676439999999,
#   -73.98571919999999,
#   'Mimi Hines',
#   ['park', 'point_of_interest', 'establishment'],
#   0],
#  [40.7604336,
#   -73.98231249999999,
#   '745 Plaza (Public Plaza)',
#   ['park', 'point_of_interest', 'establishment'],
#   0],
#  [40.7600733,
#   -73.98182249999999,
#   'Red Ornements',
#   ['campground', 'lodging', 'park', 'point_of_interest', 'establishment'],
#   0],
#  [40.7597025,
#   -73.98098279999999,
#   'Lilholts Pooley Pool',
#   ['park', 'point_of_interest', 'establishment'],
#   0],
#  [40.7568082,
#   -73.9815777,
#   'Edward J. Minskoff Equities and Marsh & McLennan pocket park',
#   ['park', 'point_of_interest', 'establishment'],
#   0],
#  [40.7573681,
#   -73.9835798,
#   "Connolly's Pub & Restaurant",
#   ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   2],
#  [40.757498,
#   -73.986654,
#   "Carmine's Italian Restaurant - Times Square",
#   ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   2],
#  [40.7594099,
#   -73.98222,
#   "Del Frisco's Double Eagle Steakhouse",
#   ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   4],
#  [40.7579436,
#   -73.9851237,
#   'Planet Hollywood',
#   ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   2],
#  [40.7595183,
#   -73.9847419,
#   'Olive Garden Italian Restaurant',
#   ['meal_takeaway',
#    'bar',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   2],
#  [40.7589876,
#   -73.9863247,
#   'The View Restaurant & Lounge',
#   ['night_club',
#    'bar',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   4],
#  [40.76032319999999,
#   -73.98856839999999,
#   'Scarlatto',
#   ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   3],
#  [40.7584328,
#   -73.9892194,
#   'Shake Shack',
#   ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   2],
#  [40.7599972,
#   -73.9867421,
#   'Trattoria Trecolori',
#   ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   2],
#  [40.7583364,
#   -73.9841591,
#   'Havana Central Times Square',
#   ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   2],
#  [40.756511,
#   -73.984641,
#   'The Lambs Club',
#   ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   3],
#  [40.7618723,
#   -73.98343559999999,
#   'Ellen’s Stardust',
#   ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   2],
#  [40.7576912,
#   -73.9885419,
#   'Green Symphony',
#   ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   1],
#  [40.76088499999999,
#   -73.9863,
#   'La Masseria',
#   ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   3],
#  [40.7572071,
#   -73.9863737,
#   'Bubba Gump Shrimp Co.',
#   ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   2],
#  [40.75799560000001,
#   -73.9828606,
#   'Utsav',
#   ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   2],
#  [40.757732,
#   -73.987218,
#   'Bowlmor Times Square',
#   ['bowling_alley',
#    'bar',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   3],
#  [40.7579198,
#   -73.9852157,
#   'Buca di Beppo Italian Restaurant',
#   ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   2],
#  [40.7574092,
#   -73.9837409,
#   'The Perfect Pint',
#   ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   2],
#  [40.7581079,
#   -73.9842178,
#   'Le Marais',
#   ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   3]]

# %%
# total_results = []

# def findPlaces(pagetoken = None):
#     lat, lng = ('40.7589','-73.9851')
#     radius=420
#     type = "restaurant"
#     url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={lat},{lng}&radius={radius}&fields=name,geometry,types,price_level&type={type}&key={APIKEY}{pagetoken}".format(lat = lat, lng = lng, radius = radius, type = type,APIKEY = APIKEY, pagetoken = "&pagetoken="+pagetoken if pagetoken else "")
#     print(url)

#     response = requests.get(url)
#     res = json.loads(response.text)
#     print("here results ---->>> ", len(res["results"]))

#     for result in res["results"]:
# #         info = ";".join(map(str,[result["name"],result["geometry"]["location"]["lat"],result["geometry"]["location"]["lng"],result.get("rating",0),result["place_id"]]))
# #         print(info)

#         place_name = result['name']
#         latitude = result["geometry"]["location"]["lat"]
#         longitude = result["geometry"]["location"]["lng"]
#         place_type = result.get("types",0)
#         price_level = result.get("price_level",0)
# #         print([place_type, place_name, latitude, longitude])
#         total_results.append([latitude, longitude, place_name,place_type,price_level])
# #         total_results.append(result)
#     pagetoken = res.get("next_page_token",None)

#     print("here -->> ", pagetoken)

#     return pagetoken

# pagetoken = None

# while True:
#      pagetoken = findPlaces(pagetoken=pagetoken)
#      import time
#      time.sleep(5)

#      if not pagetoken:
#          break

# %%
# total_results
# types = ["bar","cafe","park","restaurant"]
# types = ["bar","cafe","casino","movie_theater","night_club","park","restaurant","shopping_mall","zoo"]
# for type in types:
#     print(type)
# Out:
# bar
# cafe
# park
# restaurant

# %%
import pandas as pd

df = pd.DataFrame(data=total_results, columns =["latitude", "longitude", "place_name","place_type","price_level"]) 
df
# Out:
#       latitude  longitude                            place_name  \
# 0    40.759410 -73.982220  Del Frisco's Double Eagle Steakhouse
# 1    40.759518 -73.984742       Olive Garden Italian Restaurant
# 2    40.758988 -73.986325          The View Restaurant & Lounge
# 3    40.759997 -73.986742                   Trattoria Trecolori
# 4    40.758336 -73.984159           Havana Central Times Square
# ..         ...        ...                                   ...
# 124  40.757996 -73.982861                                 Utsav
# 125  40.757732 -73.987218                  Bowlmor Times Square
# 126  40.757920 -73.985216      Buca di Beppo Italian Restaurant
# 127  40.757409 -73.983741                      The Perfect Pint
# 128  40.758108 -73.984218                             Le Marais
#
#                                             place_type  price_level
# 0    [bar, restaurant, food, point_of_interest, est...            4
# 1    [meal_takeaway, bar, restaurant, food, point_o...            2
# 2    [night_club, bar, restaurant, food, point_of_i...            4
# 3    [bar, restaurant, food, point_of_interest, est...            2
# 4    [bar, restaurant, food, point_of_interest, est...            2
# ..                                                 ...          ...
# 124  [bar, restaurant, food, point_of_interest, est...            2
# 125  [bowling_alley, bar, restaurant, food, point_o...            3
# 126  [restaurant, food, point_of_interest, establis...            2
# 127  [bar, restaurant, food, point_of_interest, est...            2
# 128  [restaurant, food, point_of_interest, establis...            3
#
# [129 rows x 5 columns]

# %%
very_expensive = df[((df["price_level"]).astype(str).str.contains('4'))]
expensive = df[((df["price_level"]).astype(str).str.contains('3'))]
moderately_priced = df[((df["price_level"]).astype(str).str.contains('2'))]
cheap = df[((df["price_level"]).astype(str).str.contains('1'))]

# %%
num_very_expensive = len(very_expensive)
num_expensive = len(expensive)
num_moderately_priced = len(moderately_priced)
num_cheap = len(cheap)

# %%
list_ranges = [num_very_expensive, num_expensive, num_moderately_priced, num_cheap]

very_expensive["place_name"].values
# Out:
# array(["Del Frisco's Double Eagle Steakhouse",
#        'The View Restaurant & Lounge', 'Le Bernardin',
#        "Del Frisco's Double Eagle Steakhouse",
#        'The View Restaurant & Lounge'], dtype=object)

# %%
import random

global establishment

if max(list_ranges) == num_very_expensive:
    price_range = ", are very expensive."
    establishment = random.choice(very_expensive["place_name"].values) 
    price_experience = "These restaurants, bars and cafes would be prohibitively expensive for" + gender_text + "."
    price_experience = "These restaurants, bars and cafes would be expensive for" + gender_text + "."
    price_experience = "These restaurants, bars and cafes would be affordable for" + gender_text + "."

if max(list_ranges) == num_expensive:
    price_range = ", are expensive."
    establishment = random.choice(expensive["place_name"].values) 

if max(list_ranges) == num_moderately_priced:
    price_range = ", are moderately expensive."
    establishment = random.choice(moderately_priced["place_name"].values) 

if max(list_ranges) == num_cheap:
    price_range = ", are quite inexpensive."
    establishment = random.choice(cheap["place_name"].values)

# %%
price_text = "Most of the eating and drinking establishments in this area, such as " + establishment + price_range

# %%
price_text
# Out:
# 'Most of the eating and drinking establishments in this area, such as Amorino Gelato and Cafe, are moderately expensive.'

# %%
#if user is in xyz household incme then this might be prohibitively expensive 
affordable 
expensive
