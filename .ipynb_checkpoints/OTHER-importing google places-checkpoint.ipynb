# %%
import requests
import json

import googlemaps

# %%
#MAKE SURE TO CHANGE RESTRICTIONS ON API KEY IF THIS EVER GOES INTO DEVT

# %%
APIKEY = "AIzaSyDqsrWWm25hteIUljBf_s8Fe2SDQuXEWSY"

total_results = []

def findPlaces(pagetoken = None):
    lat, lng = ('40.7589','-73.9851')
    radius=420
    type = "restaurant"
    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={lat},{lng}&radius={radius}&fields=name,geometry,types,price_level&type={type}&key={APIKEY}{pagetoken}".format(lat = lat, lng = lng, radius = radius, type = type,APIKEY = APIKEY, pagetoken = "&pagetoken="+pagetoken if pagetoken else "")
    print(url)
    
    response = requests.get(url)
    res = json.loads(response.text)
    print("here results ---->>> ", len(res["results"]))

    for result in res["results"]:
#         info = ";".join(map(str,[result["name"],result["geometry"]["location"]["lat"],result["geometry"]["location"]["lng"],result.get("rating",0),result["place_id"]]))
#         print(info)
        
        place_name = result['name']
        latitude = result["geometry"]["location"]["lat"]
        longitude = result["geometry"]["location"]["lng"]
        place_type = result.get("types",0)
        price_level = result.get("price_level",0)
#         print([place_type, place_name, latitude, longitude])
        total_results.append([latitude, longitude, place_name,place_type,price_level])
#         total_results.append(result)
    pagetoken = res.get("next_page_token",None)

    print("here -->> ", pagetoken)

    return pagetoken

pagetoken = None

while True:
     pagetoken = findPlaces(pagetoken=pagetoken)
     import time
     time.sleep(5)

     if not pagetoken:
         break
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=40.7589,-73.9851&radius=420&fields=name,geometry,types,price_level&type=restaurant&key=AIzaSyDqsrWWm25hteIUljBf_s8Fe2SDQuXEWSY
# here results ---->>>  20
# here -->>  CqQCHwEAAMsGjYvWZ3TXg0yvn8-TsnHqWThNJ2vxEd4432iLYaqmWl3BF7nezEetKOnz8Of4kEb8Q7-aZ7lkQRtKlyEpXnuENVhqqhnaiIOQafn0sgg3qnInkbenWU-plnVZjGnLqp-H3rHuztlIPShnB-C5MwmKve2RxnAcbCSS0f3uYvDQ67KGcEbnNw7uL9BphfnLeYPD_A5B4b7lkqaRSTnicoO0sBnBjUeNLLsG-FmFMvrv2bX1zDcng1zQAbkQgm5NPrex6tdZ7ebIl4wmyv-RPSDqY0m5nWwHvZon1I-aKdR5aSWFu7ZdtM3c1NrYQY0MEmIhOMP0dDybmu1Twe6LuIi2-qZN72P3He9jehJVozTbZdrl2ryVT2iAnDnvbf1hEhIQbUCLstML68KmQRMOfw_BQRoU62TZv5EZngCKla_mpK3B1aWXQ9o
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=40.7589,-73.9851&radius=420&fields=name,geometry,types,price_level&type=restaurant&key=AIzaSyDqsrWWm25hteIUljBf_s8Fe2SDQuXEWSY&pagetoken=CqQCHwEAAMsGjYvWZ3TXg0yvn8-TsnHqWThNJ2vxEd4432iLYaqmWl3BF7nezEetKOnz8Of4kEb8Q7-aZ7lkQRtKlyEpXnuENVhqqhnaiIOQafn0sgg3qnInkbenWU-plnVZjGnLqp-H3rHuztlIPShnB-C5MwmKve2RxnAcbCSS0f3uYvDQ67KGcEbnNw7uL9BphfnLeYPD_A5B4b7lkqaRSTnicoO0sBnBjUeNLLsG-FmFMvrv2bX1zDcng1zQAbkQgm5NPrex6tdZ7ebIl4wmyv-RPSDqY0m5nWwHvZon1I-aKdR5aSWFu7ZdtM3c1NrYQY0MEmIhOMP0dDybmu1Twe6LuIi2-qZN72P3He9jehJVozTbZdrl2ryVT2iAnDnvbf1hEhIQbUCLstML68KmQRMOfw_BQRoU62TZv5EZngCKla_mpK3B1aWXQ9o
# 1   40.757498 -73.986654        Carmine's Italian Restaurant - Times Square
# 2   40.759410 -73.982220               Del Frisco's Double Eagle Steakhouse
# 3   40.757944 -73.985124                                   Planet Hollywood
# 4   40.759518 -73.984742                    Olive Garden Italian Restaurant
# 5   40.757035 -73.986611                                     Hard Rock Cafe
# 6   40.758988 -73.986325                       The View Restaurant & Lounge
# 7   40.760323 -73.988568                                          Scarlatto
# 8   40.758433 -73.989219                                        Shake Shack
# 9   40.759997 -73.986742                                Trattoria Trecolori
# 10  40.758336 -73.984159                        Havana Central Times Square
# 11  40.756511 -73.984641                                     The Lambs Club
# 12  40.761872 -73.983436                                   Ellen’s Stardust
# 13  40.757691 -73.988542                                     Green Symphony
# 14  40.760885 -73.986300                                        La Masseria
# 15  40.757207 -73.986374                              Bubba Gump Shrimp Co.
# 16  40.757996 -73.982861                                              Utsav
# 17  40.757920 -73.985216                   Buca di Beppo Italian Restaurant
# 18  40.757409 -73.983741                                   The Perfect Pint
# 19  40.758108 -73.984218                                          Le Marais
# 20  40.759619 -73.984679                                           R Lounge
# 21  40.759044 -73.988787  Lucky Cheng's Drag Queen Show Place, Restauran...
# 22  40.758052 -73.984062                            Minar Indian Restaurant
# 23  40.759246 -73.986292                                         Bond 45 NY
# 24  40.759499 -73.982245                                              Bocca
# 25  40.761105 -73.982507                                        Bobby Van's
# 26  40.760556 -73.986134                          Hurley's Restaurant & Bar
# 27  40.761431 -73.982328                           Ruth's Chris Steak House
# 28  40.759906 -73.986680                                 Glass House Tavern
# 29  40.762222 -73.985619                                           Toloache
# 30  40.756784 -73.985128                   Virgil's Real BBQ - Times Square
# 31  40.760932 -73.987522                               Latitude Bar & Grill
# 32  40.760348 -73.983025                                    Hale and Hearty
# 33  40.756978 -73.988775                                         Dallas BBQ
# 34  40.760908 -73.985335                                          Da Marino
# 35  40.756148 -73.984795                                           BXL Cafe
# 36  40.757617 -73.984364                                         O'Lunney's
# 37  40.759310 -73.982533                                          48 Lounge
# 38  40.760728 -73.986514                            Pongsri Thai Restaurant
# 39  40.761663 -73.985181                                            Natsumi
# 40  40.761569 -73.981805                                       Le Bernardin
# 41  40.758677 -73.982513                                           fresh&co
# 42  40.756617 -73.984911                                    Osteria al Doge
# 43  40.756077 -73.982699                                      The Red Flame
# 44  40.756393 -73.988039                                         McDonald's
# 45  40.757556 -73.984034                      Grace Lounge At the Grace Htl
# 46  40.760978 -73.985510                                Serafina Time Hotel
# 47  40.761916 -73.987732                            Churrascaria Plataforma
# 48  40.758834 -73.988843                                 Subway Restaurants
# 49  40.759245 -73.988036                                  Daniela Trattoria
# 50  40.760141 -73.989071                                          Joe Allen
# 51  40.759969 -73.988935                     Frankie & Johnnie's Steakhouse
# 52  40.759983 -73.982845                                       Pasta Lovers
# 53  40.759426 -73.988742                                       Kodama Sushi
# 54  40.757191 -73.984426                                           Red Moon
# 55  40.755854 -73.982222                                  db Bistro Moderne
# 56  40.760012 -73.989010                                               Orso
# 57  40.760357 -73.988969                                           Barbetta
# 58  40.756419 -73.984331                                        Saju Bistro
# 59  40.761078 -73.983519                              Majestic Delicatessen
#
#                                                     3  4
# 0   [restaurant, food, point_of_interest, establis...  2
# 1   [restaurant, food, point_of_interest, establis...  2
# 2   [bar, restaurant, food, point_of_interest, est...  4
# 3   [restaurant, food, point_of_interest, establis...  2
# 4   [meal_takeaway, bar, restaurant, food, point_o...  2
# 5   [restaurant, food, point_of_interest, establis...  2
# 6   [night_club, bar, restaurant, food, point_of_i...  4
# 7   [restaurant, food, point_of_interest, establis...  3
# 8   [restaurant, food, point_of_interest, establis...  2
# 9   [bar, restaurant, food, point_of_interest, est...  2
# 10  [bar, restaurant, food, point_of_interest, est...  2
# 11  [bar, restaurant, food, point_of_interest, est...  3
# 12  [restaurant, food, point_of_interest, establis...  2
# 13  [restaurant, food, point_of_interest, establis...  1
# 14  [bar, restaurant, food, point_of_interest, est...  3
# 15  [restaurant, food, point_of_interest, establis...  2
# 16  [bar, restaurant, food, point_of_interest, est...  2
# 17  [restaurant, food, point_of_interest, establis...  2
# 18  [bar, restaurant, food, point_of_interest, est...  2
# 19  [restaurant, food, point_of_interest, establis...  3
# 20  [night_club, bar, restaurant, food, point_of_i...  2
# 21  [restaurant, food, point_of_interest, establis...  3
# 22  [restaurant, food, point_of_interest, establis...  1
# 23  [night_club, bar, restaurant, food, point_of_i...  2
# 24  [restaurant, food, point_of_interest, establis...  2
# 25  [bar, restaurant, food, point_of_interest, est...  3
# 26  [restaurant, bar, food, point_of_interest, est...  2
# 27  [restaurant, food, point_of_interest, establis...  4
# 28  [bar, restaurant, food, point_of_interest, est...  2
# 29  [restaurant, food, point_of_interest, establis...  2
# 30  [restaurant, food, point_of_interest, establis...  2
# 31  [restaurant, bar, food, point_of_interest, est...  2
# 32  [meal_delivery, meal_takeaway, restaurant, foo...  2
# 33  [bar, restaurant, food, point_of_interest, est...  2
# 34  [restaurant, food, point_of_interest, establis...  3
# 35  [restaurant, food, point_of_interest, establis...  2
# 36  [bar, restaurant, food, point_of_interest, est...  2
# 37  [night_club, bar, restaurant, food, point_of_i...  3
# 38  [restaurant, food, point_of_interest, establis...  2
# 39  [bar, restaurant, food, point_of_interest, est...  2
# 40  [bar, restaurant, food, point_of_interest, est...  4
# 41  [restaurant, food, point_of_interest, establis...  0
# 42  [restaurant, food, point_of_interest, establis...  2
# 43  [meal_takeaway, cafe, restaurant, food, point_...  1
# 44  [cafe, restaurant, food, point_of_interest, st...  1
# 45  [restaurant, food, point_of_interest, establis...  0
# 46  [restaurant, food, point_of_interest, establis...  2
# 47  [restaurant, food, point_of_interest, establis...  3
# 48  [restaurant, food, point_of_interest, establis...  1
# 49  [restaurant, food, point_of_interest, establis...  2
# 50  [restaurant, food, point_of_interest, establis...  2
# 51  [restaurant, food, point_of_interest, establis...  3
# 52  [bar, restaurant, food, point_of_interest, sto...  2
# 53  [bar, restaurant, food, point_of_interest, est...  2
# 54  [restaurant, food, point_of_interest, establis...  2
# 55  [bar, restaurant, food, point_of_interest, est...  3
# 56  [restaurant, food, point_of_interest, establis...  3
# 57  [restaurant, food, point_of_interest, establis...  3
# 58  [bar, restaurant, food, point_of_interest, est...  3
# 59  [restaurant, food, point_of_interest, store, e...  2

# %%
#which place types to import 
#figure out how to get more than 60
#loop through each location - but this is already sorted 
#but need to figure out loop for each location and each place type
